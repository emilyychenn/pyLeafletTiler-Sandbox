# %%
import sys,os

# %%
target_dir='/Users/Emily/Leaflet_Test/CD31_tiles'

# %%
cd $target_dir
# Out:
# /Users/emily/Leaflet_Test/CD31_tiles

# %%
pwd
# Out:
# '/Users/emily/Leaflet_Test/CD31_tiles'

# %%
# my computer seems to be missing the libpng delegate for imagemagick; can only read png
# magick identify -list format --> command (command line) to show which file formats can be read
# therefore must convert image to jpg before making into tiles
tile_width = 256
tile_height = 256
image_width = 4096
image_height = 4096 # image must be square in order to generate non-stretched map tiles!!!
zoom_level = 5


while zoom_level>0:
    # !mkdir $zoom_level 2> /dev/null
    
    cmd = 'convert CD31.jpg -scale {0}x{1}\! {2}/full_zoom.png'.format(
            image_width, image_height, zoom_level)
    print(cmd)
    os.system(cmd) # to run the command
    
#     cmd2 = 'convert multiply.png -scale $image_width x$image_height\! $zoomlevel/full_zoom.png'
#     print(cmd2)
#     os.system(cmd2)

    cmd3 = 'convert -crop 256X256 +repage {0}/full_zoom.png {0}/tiles_%d.png'.format(zoom_level)
    print(cmd3) 
    os.system(cmd3)
   
    zoom_level -= 1
    image_width = image_width//2
    image_height = image_height//2
# Out:
# convert CD31.jpg -scale 4096x4096\! 5/full_zoom.png
# convert -crop 256X256 +repage 5/full_zoom.png 5/tiles_%d.png
# convert CD31.jpg -scale 2048x2048\! 4/full_zoom.png
# convert -crop 256X256 +repage 4/full_zoom.png 4/tiles_%d.png
# convert CD31.jpg -scale 1024x1024\! 3/full_zoom.png
# convert -crop 256X256 +repage 3/full_zoom.png 3/tiles_%d.png
# convert CD31.jpg -scale 512x512\! 2/full_zoom.png
# convert -crop 256X256 +repage 2/full_zoom.png 2/tiles_%d.png
# convert CD31.jpg -scale 256x256\! 1/full_zoom.png
# convert -crop 256X256 +repage 1/full_zoom.png 1/tiles_%d.png

# %%
image_width = 4096
zoom_level = 5

while zoom_level>0:
    fname = !ls "$zoom_level"/tiles_*.png
    total_tiles = len(fname) # To get this number, look at the number of tiles generated, find the last tile number & add 1
    print(total_tiles, zoom_level) # e.g. tiles_99.png => total_tiles = 100
    tiles_per_column = image_width/tile_width

    row = 0
    column = 0
    for i in range(total_tiles):
        filename = "{0}/tiles_{1}.png".format(zoom_level, i) # current filename
        target = "{0}/map_{1}_{2}.png".format(zoom_level, column, row) # new filename

        print('cp -f {0} {1}'.format(filename, target))
        # !mv $filename $target

        column = column + 1
        if column >= tiles_per_column:
            column = 0
            row = row + 1
            
    image_width = image_width//2
    zoom_level -= 1
# Out:
# 256 5
# cp -f 5/tiles_0.png 5/map_0_0.png
# cp -f 5/tiles_1.png 5/map_1_0.png
# cp -f 5/tiles_2.png 5/map_2_0.png
# cp -f 5/tiles_3.png 5/map_3_0.png
# cp -f 5/tiles_4.png 5/map_4_0.png
# cp -f 5/tiles_5.png 5/map_5_0.png
# cp -f 5/tiles_6.png 5/map_6_0.png
# cp -f 5/tiles_7.png 5/map_7_0.png
# cp -f 5/tiles_8.png 5/map_8_0.png
# cp -f 5/tiles_9.png 5/map_9_0.png
# cp -f 5/tiles_10.png 5/map_10_0.png
# cp -f 5/tiles_11.png 5/map_11_0.png
# cp -f 5/tiles_12.png 5/map_12_0.png
# cp -f 5/tiles_13.png 5/map_13_0.png
# cp -f 5/tiles_14.png 5/map_14_0.png
# cp -f 5/tiles_15.png 5/map_15_0.png
# cp -f 5/tiles_16.png 5/map_0_1.png
# cp -f 5/tiles_17.png 5/map_1_1.png
# cp -f 5/tiles_18.png 5/map_2_1.png
# cp -f 5/tiles_19.png 5/map_3_1.png
# cp -f 5/tiles_20.png 5/map_4_1.png
# cp -f 5/tiles_21.png 5/map_5_1.png
# cp -f 5/tiles_22.png 5/map_6_1.png
# cp -f 5/tiles_23.png 5/map_7_1.png
# cp -f 5/tiles_24.png 5/map_8_1.png
# cp -f 5/tiles_25.png 5/map_9_1.png
# cp -f 5/tiles_26.png 5/map_10_1.png
# cp -f 5/tiles_27.png 5/map_11_1.png
# cp -f 5/tiles_28.png 5/map_12_1.png
# cp -f 5/tiles_29.png 5/map_13_1.png
# cp -f 5/tiles_30.png 5/map_14_1.png
# cp -f 5/tiles_31.png 5/map_15_1.png
# cp -f 5/tiles_32.png 5/map_0_2.png
# cp -f 5/tiles_33.png 5/map_1_2.png
# cp -f 5/tiles_34.png 5/map_2_2.png
# cp -f 5/tiles_35.png 5/map_3_2.png
# cp -f 5/tiles_36.png 5/map_4_2.png
# cp -f 5/tiles_37.png 5/map_5_2.png
# cp -f 5/tiles_38.png 5/map_6_2.png
# cp -f 5/tiles_39.png 5/map_7_2.png
# cp -f 5/tiles_40.png 5/map_8_2.png
# cp -f 5/tiles_41.png 5/map_9_2.png
# cp -f 5/tiles_42.png 5/map_10_2.png
# cp -f 5/tiles_43.png 5/map_11_2.png
# cp -f 5/tiles_44.png 5/map_12_2.png
# cp -f 5/tiles_45.png 5/map_13_2.png
# cp -f 5/tiles_46.png 5/map_14_2.png
# cp -f 5/tiles_47.png 5/map_15_2.png
# cp -f 5/tiles_48.png 5/map_0_3.png
# cp -f 5/tiles_49.png 5/map_1_3.png
# cp -f 5/tiles_50.png 5/map_2_3.png
# cp -f 5/tiles_51.png 5/map_3_3.png
# cp -f 5/tiles_52.png 5/map_4_3.png
# cp -f 5/tiles_53.png 5/map_5_3.png
# cp -f 5/tiles_54.png 5/map_6_3.png
# cp -f 5/tiles_55.png 5/map_7_3.png
# cp -f 5/tiles_56.png 5/map_8_3.png
# cp -f 5/tiles_57.png 5/map_9_3.png
# cp -f 5/tiles_58.png 5/map_10_3.png
# cp -f 5/tiles_59.png 5/map_11_3.png
# cp -f 5/tiles_60.png 5/map_12_3.png
# cp -f 5/tiles_61.png 5/map_13_3.png
# cp -f 5/tiles_62.png 5/map_14_3.png
# cp -f 5/tiles_63.png 5/map_15_3.png
# cp -f 5/tiles_64.png 5/map_0_4.png
# cp -f 5/tiles_65.png 5/map_1_4.png
# cp -f 5/tiles_66.png 5/map_2_4.png
# cp -f 5/tiles_67.png 5/map_3_4.png
# cp -f 5/tiles_68.png 5/map_4_4.png
# cp -f 5/tiles_69.png 5/map_5_4.png
# cp -f 5/tiles_70.png 5/map_6_4.png
# cp -f 5/tiles_71.png 5/map_7_4.png
# cp -f 5/tiles_72.png 5/map_8_4.png
# cp -f 5/tiles_73.png 5/map_9_4.png
# cp -f 5/tiles_74.png 5/map_10_4.png
# cp -f 5/tiles_75.png 5/map_11_4.png
# cp -f 5/tiles_76.png 5/map_12_4.png
# cp -f 5/tiles_77.png 5/map_13_4.png
# cp -f 5/tiles_78.png 5/map_14_4.png
# cp -f 5/tiles_79.png 5/map_15_4.png
# cp -f 5/tiles_80.png 5/map_0_5.png
# cp -f 5/tiles_81.png 5/map_1_5.png
# cp -f 5/tiles_82.png 5/map_2_5.png
# cp -f 5/tiles_83.png 5/map_3_5.png
# cp -f 5/tiles_84.png 5/map_4_5.png
# cp -f 5/tiles_85.png 5/map_5_5.png
# cp -f 5/tiles_86.png 5/map_6_5.png
# cp -f 5/tiles_87.png 5/map_7_5.png
# cp -f 5/tiles_88.png 5/map_8_5.png
# cp -f 5/tiles_89.png 5/map_9_5.png
# cp -f 5/tiles_90.png 5/map_10_5.png
# cp -f 5/tiles_91.png 5/map_11_5.png
# cp -f 5/tiles_92.png 5/map_12_5.png
# cp -f 5/tiles_93.png 5/map_13_5.png
# cp -f 5/tiles_94.png 5/map_14_5.png
# cp -f 5/tiles_95.png 5/map_15_5.png
# cp -f 5/tiles_96.png 5/map_0_6.png
# cp -f 5/tiles_97.png 5/map_1_6.png
# cp -f 5/tiles_98.png 5/map_2_6.png
# cp -f 5/tiles_99.png 5/map_3_6.png
# cp -f 5/tiles_100.png 5/map_4_6.png
# cp -f 5/tiles_101.png 5/map_5_6.png
# cp -f 5/tiles_102.png 5/map_6_6.png
# cp -f 5/tiles_103.png 5/map_7_6.png
# cp -f 5/tiles_104.png 5/map_8_6.png
# cp -f 5/tiles_105.png 5/map_9_6.png
# cp -f 5/tiles_106.png 5/map_10_6.png
# cp -f 5/tiles_107.png 5/map_11_6.png
# cp -f 5/tiles_108.png 5/map_12_6.png
# cp -f 5/tiles_109.png 5/map_13_6.png
# cp -f 5/tiles_110.png 5/map_14_6.png
# cp -f 5/tiles_111.png 5/map_15_6.png
# cp -f 5/tiles_112.png 5/map_0_7.png
# cp -f 5/tiles_113.png 5/map_1_7.png
# cp -f 5/tiles_114.png 5/map_2_7.png
# cp -f 5/tiles_115.png 5/map_3_7.png
# cp -f 5/tiles_116.png 5/map_4_7.png
# cp -f 5/tiles_117.png 5/map_5_7.png
# cp -f 5/tiles_118.png 5/map_6_7.png
# cp -f 5/tiles_119.png 5/map_7_7.png
# cp -f 5/tiles_120.png 5/map_8_7.png
# cp -f 5/tiles_121.png 5/map_9_7.png
# cp -f 5/tiles_122.png 5/map_10_7.png
# cp -f 5/tiles_123.png 5/map_11_7.png
# cp -f 5/tiles_124.png 5/map_12_7.png
# cp -f 5/tiles_125.png 5/map_13_7.png
# cp -f 5/tiles_126.png 5/map_14_7.png
# cp -f 5/tiles_127.png 5/map_15_7.png
# cp -f 5/tiles_128.png 5/map_0_8.png
# cp -f 5/tiles_129.png 5/map_1_8.png
# cp -f 5/tiles_130.png 5/map_2_8.png
# cp -f 5/tiles_131.png 5/map_3_8.png
# cp -f 5/tiles_132.png 5/map_4_8.png
# cp -f 5/tiles_133.png 5/map_5_8.png
# cp -f 5/tiles_134.png 5/map_6_8.png
# cp -f 5/tiles_135.png 5/map_7_8.png
# cp -f 5/tiles_136.png 5/map_8_8.png
# cp -f 5/tiles_137.png 5/map_9_8.png
# cp -f 5/tiles_138.png 5/map_10_8.png
# cp -f 5/tiles_139.png 5/map_11_8.png
# cp -f 5/tiles_140.png 5/map_12_8.png
# cp -f 5/tiles_141.png 5/map_13_8.png
# cp -f 5/tiles_142.png 5/map_14_8.png
# cp -f 5/tiles_143.png 5/map_15_8.png
# cp -f 5/tiles_144.png 5/map_0_9.png
# cp -f 5/tiles_145.png 5/map_1_9.png
# cp -f 5/tiles_146.png 5/map_2_9.png
# cp -f 5/tiles_147.png 5/map_3_9.png
# cp -f 5/tiles_148.png 5/map_4_9.png
# cp -f 5/tiles_149.png 5/map_5_9.png
# cp -f 5/tiles_150.png 5/map_6_9.png
# cp -f 5/tiles_151.png 5/map_7_9.png
# cp -f 5/tiles_152.png 5/map_8_9.png
# cp -f 5/tiles_153.png 5/map_9_9.png
# cp -f 5/tiles_154.png 5/map_10_9.png
# cp -f 5/tiles_155.png 5/map_11_9.png
# cp -f 5/tiles_156.png 5/map_12_9.png
# cp -f 5/tiles_157.png 5/map_13_9.png
# cp -f 5/tiles_158.png 5/map_14_9.png
# cp -f 5/tiles_159.png 5/map_15_9.png
# cp -f 5/tiles_160.png 5/map_0_10.png
# cp -f 5/tiles_161.png 5/map_1_10.png
# cp -f 5/tiles_162.png 5/map_2_10.png
# cp -f 5/tiles_163.png 5/map_3_10.png
# cp -f 5/tiles_164.png 5/map_4_10.png
# cp -f 5/tiles_165.png 5/map_5_10.png
# cp -f 5/tiles_166.png 5/map_6_10.png
# cp -f 5/tiles_167.png 5/map_7_10.png
# cp -f 5/tiles_168.png 5/map_8_10.png
# cp -f 5/tiles_169.png 5/map_9_10.png
# cp -f 5/tiles_170.png 5/map_10_10.png
# cp -f 5/tiles_171.png 5/map_11_10.png
# cp -f 5/tiles_172.png 5/map_12_10.png
# cp -f 5/tiles_173.png 5/map_13_10.png
# cp -f 5/tiles_174.png 5/map_14_10.png
# cp -f 5/tiles_175.png 5/map_15_10.png
# cp -f 5/tiles_176.png 5/map_0_11.png
# cp -f 5/tiles_177.png 5/map_1_11.png
# cp -f 5/tiles_178.png 5/map_2_11.png
# cp -f 5/tiles_179.png 5/map_3_11.png
# cp -f 5/tiles_180.png 5/map_4_11.png
# cp -f 5/tiles_181.png 5/map_5_11.png
# cp -f 5/tiles_182.png 5/map_6_11.png
# cp -f 5/tiles_183.png 5/map_7_11.png
# cp -f 5/tiles_184.png 5/map_8_11.png
# cp -f 5/tiles_185.png 5/map_9_11.png
# cp -f 5/tiles_186.png 5/map_10_11.png
# cp -f 5/tiles_187.png 5/map_11_11.png
# cp -f 5/tiles_188.png 5/map_12_11.png
# cp -f 5/tiles_189.png 5/map_13_11.png
# cp -f 5/tiles_190.png 5/map_14_11.png
# cp -f 5/tiles_191.png 5/map_15_11.png
# cp -f 5/tiles_192.png 5/map_0_12.png
# cp -f 5/tiles_193.png 5/map_1_12.png
# cp -f 5/tiles_194.png 5/map_2_12.png
# cp -f 5/tiles_195.png 5/map_3_12.png
# cp -f 5/tiles_196.png 5/map_4_12.png
# cp -f 5/tiles_197.png 5/map_5_12.png
# cp -f 5/tiles_198.png 5/map_6_12.png
# cp -f 5/tiles_199.png 5/map_7_12.png
# cp -f 5/tiles_200.png 5/map_8_12.png
# cp -f 5/tiles_201.png 5/map_9_12.png
# cp -f 5/tiles_202.png 5/map_10_12.png
# cp -f 5/tiles_203.png 5/map_11_12.png
# cp -f 5/tiles_204.png 5/map_12_12.png
# cp -f 5/tiles_205.png 5/map_13_12.png
# cp -f 5/tiles_206.png 5/map_14_12.png
# cp -f 5/tiles_207.png 5/map_15_12.png
# cp -f 5/tiles_208.png 5/map_0_13.png
# cp -f 5/tiles_209.png 5/map_1_13.png
# cp -f 5/tiles_210.png 5/map_2_13.png
# cp -f 5/tiles_211.png 5/map_3_13.png
# cp -f 5/tiles_212.png 5/map_4_13.png
# cp -f 5/tiles_213.png 5/map_5_13.png
# cp -f 5/tiles_214.png 5/map_6_13.png
# cp -f 5/tiles_215.png 5/map_7_13.png
# cp -f 5/tiles_216.png 5/map_8_13.png
# cp -f 5/tiles_217.png 5/map_9_13.png
# cp -f 5/tiles_218.png 5/map_10_13.png
# cp -f 5/tiles_219.png 5/map_11_13.png
# cp -f 5/tiles_220.png 5/map_12_13.png
# cp -f 5/tiles_221.png 5/map_13_13.png
# cp -f 5/tiles_222.png 5/map_14_13.png
# cp -f 5/tiles_223.png 5/map_15_13.png
# cp -f 5/tiles_224.png 5/map_0_14.png
# cp -f 5/tiles_225.png 5/map_1_14.png
# cp -f 5/tiles_226.png 5/map_2_14.png
# cp -f 5/tiles_227.png 5/map_3_14.png
# cp -f 5/tiles_228.png 5/map_4_14.png
# cp -f 5/tiles_229.png 5/map_5_14.png
# cp -f 5/tiles_230.png 5/map_6_14.png
# cp -f 5/tiles_231.png 5/map_7_14.png
# cp -f 5/tiles_232.png 5/map_8_14.png
# cp -f 5/tiles_233.png 5/map_9_14.png
# cp -f 5/tiles_234.png 5/map_10_14.png
# cp -f 5/tiles_235.png 5/map_11_14.png
# cp -f 5/tiles_236.png 5/map_12_14.png
# cp -f 5/tiles_237.png 5/map_13_14.png
# cp -f 5/tiles_238.png 5/map_14_14.png
# cp -f 5/tiles_239.png 5/map_15_14.png
# cp -f 5/tiles_240.png 5/map_0_15.png
# cp -f 5/tiles_241.png 5/map_1_15.png
# cp -f 5/tiles_242.png 5/map_2_15.png
# cp -f 5/tiles_243.png 5/map_3_15.png
# cp -f 5/tiles_244.png 5/map_4_15.png
# cp -f 5/tiles_245.png 5/map_5_15.png
# cp -f 5/tiles_246.png 5/map_6_15.png
# cp -f 5/tiles_247.png 5/map_7_15.png
# cp -f 5/tiles_248.png 5/map_8_15.png
# cp -f 5/tiles_249.png 5/map_9_15.png
# cp -f 5/tiles_250.png 5/map_10_15.png
# cp -f 5/tiles_251.png 5/map_11_15.png
# cp -f 5/tiles_252.png 5/map_12_15.png
# cp -f 5/tiles_253.png 5/map_13_15.png
# cp -f 5/tiles_254.png 5/map_14_15.png
# cp -f 5/tiles_255.png 5/map_15_15.png
# 64 4
# cp -f 4/tiles_0.png 4/map_0_0.png
# cp -f 4/tiles_1.png 4/map_1_0.png
# cp -f 4/tiles_2.png 4/map_2_0.png
# cp -f 4/tiles_3.png 4/map_3_0.png
# cp -f 4/tiles_4.png 4/map_4_0.png
# cp -f 4/tiles_5.png 4/map_5_0.png
# cp -f 4/tiles_6.png 4/map_6_0.png
# cp -f 4/tiles_7.png 4/map_7_0.png
# cp -f 4/tiles_8.png 4/map_0_1.png
# cp -f 4/tiles_9.png 4/map_1_1.png
# cp -f 4/tiles_10.png 4/map_2_1.png
# cp -f 4/tiles_11.png 4/map_3_1.png
# cp -f 4/tiles_12.png 4/map_4_1.png
# cp -f 4/tiles_13.png 4/map_5_1.png
# cp -f 4/tiles_14.png 4/map_6_1.png
# cp -f 4/tiles_15.png 4/map_7_1.png
# cp -f 4/tiles_16.png 4/map_0_2.png
# cp -f 4/tiles_17.png 4/map_1_2.png
# cp -f 4/tiles_18.png 4/map_2_2.png
# cp -f 4/tiles_19.png 4/map_3_2.png
# cp -f 4/tiles_20.png 4/map_4_2.png
# cp -f 4/tiles_21.png 4/map_5_2.png
# cp -f 4/tiles_22.png 4/map_6_2.png
# cp -f 4/tiles_23.png 4/map_7_2.png
# cp -f 4/tiles_24.png 4/map_0_3.png
# cp -f 4/tiles_25.png 4/map_1_3.png
# cp -f 4/tiles_26.png 4/map_2_3.png
# cp -f 4/tiles_27.png 4/map_3_3.png
# cp -f 4/tiles_28.png 4/map_4_3.png
# cp -f 4/tiles_29.png 4/map_5_3.png
# cp -f 4/tiles_30.png 4/map_6_3.png
# cp -f 4/tiles_31.png 4/map_7_3.png
# cp -f 4/tiles_32.png 4/map_0_4.png
# cp -f 4/tiles_33.png 4/map_1_4.png
# cp -f 4/tiles_34.png 4/map_2_4.png
# cp -f 4/tiles_35.png 4/map_3_4.png
# cp -f 4/tiles_36.png 4/map_4_4.png
# cp -f 4/tiles_37.png 4/map_5_4.png
# cp -f 4/tiles_38.png 4/map_6_4.png
# cp -f 4/tiles_39.png 4/map_7_4.png
# cp -f 4/tiles_40.png 4/map_0_5.png
# cp -f 4/tiles_41.png 4/map_1_5.png
# cp -f 4/tiles_42.png 4/map_2_5.png
# cp -f 4/tiles_43.png 4/map_3_5.png
# cp -f 4/tiles_44.png 4/map_4_5.png
# cp -f 4/tiles_45.png 4/map_5_5.png
# cp -f 4/tiles_46.png 4/map_6_5.png
# cp -f 4/tiles_47.png 4/map_7_5.png
# cp -f 4/tiles_48.png 4/map_0_6.png
# cp -f 4/tiles_49.png 4/map_1_6.png
# cp -f 4/tiles_50.png 4/map_2_6.png
# cp -f 4/tiles_51.png 4/map_3_6.png
# cp -f 4/tiles_52.png 4/map_4_6.png
# cp -f 4/tiles_53.png 4/map_5_6.png
# cp -f 4/tiles_54.png 4/map_6_6.png
# cp -f 4/tiles_55.png 4/map_7_6.png
# cp -f 4/tiles_56.png 4/map_0_7.png
# cp -f 4/tiles_57.png 4/map_1_7.png
# cp -f 4/tiles_58.png 4/map_2_7.png
# cp -f 4/tiles_59.png 4/map_3_7.png
# cp -f 4/tiles_60.png 4/map_4_7.png
# cp -f 4/tiles_61.png 4/map_5_7.png
# cp -f 4/tiles_62.png 4/map_6_7.png
# cp -f 4/tiles_63.png 4/map_7_7.png
# 16 3
# cp -f 3/tiles_0.png 3/map_0_0.png
# cp -f 3/tiles_1.png 3/map_1_0.png
# cp -f 3/tiles_2.png 3/map_2_0.png
# cp -f 3/tiles_3.png 3/map_3_0.png
# cp -f 3/tiles_4.png 3/map_0_1.png
# cp -f 3/tiles_5.png 3/map_1_1.png
# cp -f 3/tiles_6.png 3/map_2_1.png
# cp -f 3/tiles_7.png 3/map_3_1.png
# cp -f 3/tiles_8.png 3/map_0_2.png
# cp -f 3/tiles_9.png 3/map_1_2.png
# cp -f 3/tiles_10.png 3/map_2_2.png
# cp -f 3/tiles_11.png 3/map_3_2.png
# cp -f 3/tiles_12.png 3/map_0_3.png
# cp -f 3/tiles_13.png 3/map_1_3.png
# cp -f 3/tiles_14.png 3/map_2_3.png
# cp -f 3/tiles_15.png 3/map_3_3.png
# 4 2
# cp -f 2/tiles_0.png 2/map_0_0.png
# cp -f 2/tiles_1.png 2/map_1_0.png
# cp -f 2/tiles_2.png 2/map_0_1.png
# cp -f 2/tiles_3.png 2/map_1_1.png
# 1 1
# cp -f 1/tiles_0.png 1/map_0_0.png
